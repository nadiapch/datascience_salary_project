# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df1 = df
df1.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df1.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'

def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

		
## Job title and seniority
		
## Fix state Los Angeles

## Job description lenght

## Competitor count

## hourly wage to annual

#remove new line from job title

# %%
df1['job_simp'] = df1['Job Title'].apply(title_simplifier)

# %%
df1.job_simp.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: job_simp, dtype: int64

# %%
df1['seniority'] = df1['Job Title'].apply(seniority)

# %%
df1.seniority.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniority, dtype: int64

# %%
df1.job_state.value_counts()
# Out:
#  CA             151
#  MA             103
#  NY              72
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  NC              21
#  WA              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  DC              11
#  CO              11
#  IN              10
#  WI              10
#  UT              10
#  MO               9
#  AZ               9
#  AL               8
#  DE               6
#  GA               6
#  KY               6
#  MI               6
#  IA               5
#  CT               5
#  NE               4
#  LA               4
#  OR               4
#  NM               3
#  KS               3
#  ID               2
#  MN               2
#  RI               1
#  Los Angeles      1
#  SC               1
# Name: job_state, dtype: int64

# %%
## Fix state Los Angeles
df1['job_state'] = df1.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')

# %%
df1.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# WA     21
# NC     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# IN     10
# UT     10
# AZ      9
# MO      9
# AL      8
# MI      6
# GA      6
# DE      6
# KY      6
# IA      5
# CT      5
# OR      4
# NE      4
# LA      4
# NM      3
# KS      3
# MN      2
# ID      2
# RI      1
# SC      1
# Name: job_state, dtype: int64

# %%
## Job description lenght
df1['desc_len'] = df1['Job Description'].apply(lambda x: len(x))
df1['desc_len']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: desc_len, Length: 742, dtype: int64

# %%
## Competitor count
df1['num_comp'] = df1['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else '0')

# %%
df1['num_comp']
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    0
# 740    0
# 741    0
# Name: num_comp, Length: 742, dtype: object

# %%
## hourly wage to annual 
df1['min_salary'] = df1.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis = 1)

# %%
df1[df1.hourly ==1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          24
# 177       1          42          34
# 197       1          36          25
# 202       1          42          34
# 210       1          30          25
# 246       1          34          24
# 271       1          42          34
# 337       1          36          25
# 345       1          48          39
# 357       1          42          34
# 363       1          50          28
# 408       1          42          29
# 409       1          20          17
# 492       1          36          25
# 509       1          48          39
# 533       1          42          34
# 542       1          50          28
# 617       1          42          29
# 618       1          20          17
# 645       1          54          47
# 666       1          36          25
# 682       1          48          39
# 711       1          42          34
# 724       1          50          28

# %%
df1['max_salary'] = df1.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis = 1)

# %%
df1[df1.hourly ==1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %%
#remove new line from job title
df1['company_txt'] = df1.company_txt.apply(lambda x: x.replace('\n', ' '))

# %%
df1['company_txt']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                         ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_txt, Length: 742, dtype: object

# %%
df1.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   47.524259    0.528302    0.002695
# ...

# %%
df1.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
df1.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df1.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df1.age.hist()
# Out:
# <AxesSubplot:>

# %%
df1.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df1.boxplot(column = ['age', 'avg_salary', 'Rating'])
# Out:
# <AxesSubplot:>

# %%
df1.boxplot(column = 'Rating')
# Out:
# <AxesSubplot:>

# %%
df1[['age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.019574  0.023162  0.164188
# avg_salary  0.019574    1.000000  0.013492  0.078808
# Rating      0.023162    0.013492  1.000000 -0.012281
# desc_len    0.164188    0.078808 -0.012281  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap= True)
sns.heatmap(df1[['age', 'avg_salary', 'Rating', 'desc_len', 'num_comp']].corr(), vmax =.3, center=0, cmap=cmap, 
           square=True, linewidths=.5, cbar_kws={'shrink':.5})
# Out:
# <AxesSubplot:>

# %%
df1.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
df1_cat = df1[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue','company_txt', 'job_state', 'spark', 'aws', 'excel', 'job_simp', 'seniority']]

# %%
for i in df1_cat.columns:
    cat_num = df1_cat[i].value_counts()
    print("graph for %s: total =%d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total =200
# graph for Headquarters: total =198
# graph for Size: total =9
# graph for Type of ownership: total =11
# graph for Industry: total =60
# graph for Sector: total =25
# graph for Revenue: total =14
# graph for company_txt: total =343
# graph for job_state: total =37
# graph for spark: total =2
# graph for aws: total =2
# graph for excel: total =2
# graph for job_simp: total =7
# graph for seniority: total =3

# %%
for i in df1_cat[['Location', 'Headquarters', 'company_txt']].columns:
    cat_num = df1_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_txt: total = 20

# %%
df1.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
pd.pivot_table(df1, index = 'job_simp', values= 'avg_salary' )
# Out:
#                 avg_salary
# job_simp
# analyst          65.857843
# data engineer   105.403361
# data scientist  117.564516
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               84.853261

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df1, index = ['job_state', 'job_simp'], values = 'avg_salary').sort_values('job_state', ascending=False)
# Out:
#                           avg_salary
# job_state job_simp
# WI        na               54.000000
#           data scientist  113.500000
#           analyst          58.833333
# WA        na               97.500000
#           data scientist   99.764706
#           analyst          54.500000
# VA        na               79.300000
#           mle              87.000000
#           data scientist  108.416667
#           data engineer    96.900000
#           analyst          71.583333
# UT        data engineer   100.333333
#           analyst          54.750000
#           data scientist  140.500000
# TX        na               41.285714
#           data scientist  100.730769
#           data engineer   113.062500
# TN        data scientist   96.000000
#           data engineer   100.950000
#           analyst          13.500000
# SC        na               60.500000
# RI        analyst         100.000000
# PA        manager         109.666667
#           data engineer    91.500000
# ...

# %%
pd.pivot_table(df1, index = ['job_state', 'job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending=False)
# Out:
#                           avg_salary
# job_state job_simp
# WI        na                       4
#           data scientist           3
#           analyst                  3
# WA        na                       1
#           data scientist          17
#           analyst                  3
# VA        na                       5
#           mle                      2
#           data scientist          18
#           data engineer           10
#           analyst                  6
# UT        data engineer            3
#           analyst                  4
#           data scientist           3
# TX        na                       7
#           data scientist          13
#           data engineer            8
# TN        data scientist           1
#           data engineer           10
#           analyst                  2
# SC        na                       1
# RI        analyst                  1
# PA        manager                  3
#           data engineer            1
# ...

# %%
pd.pivot_table(df1[df1.job_simp == 'data scientist'], index = ['job_state'], values = 'avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#            avg_salary
# job_state
# DC         149.000000
# CA         142.522059
# UT         140.500000
# MO         127.666667
# IL         117.233333
# NC         117.000000
# NY         115.250000
# MA         113.750000
# WI         113.500000
# PA         113.333333
# MD         109.115385
# CO         108.666667
# VA         108.416667
# NJ         106.875000
# MI         106.625000
# OH         105.285714
# TX         100.730769
# WA          99.764706
# OR          98.500000
# FL          97.357143
# TN          96.000000
# IN          84.500000
# KY          84.000000
# CT          84.000000
# GA          81.333333
# NM          74.333333
# AZ          69.500000

# %%
df1.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
# rating, industry, sector, revenue, number of competitors, hourly, employer provided, python, r, spark, aws, excel, dec_len, type of ownership

# %%
df1_pivots = df1[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'employer_provided', 'python_yn', 'R_yn', 'spark', 'aws', 'excel', 'Type of ownership', 'avg_salary']]

# %%
for i in df1_pivots.columns:
    print(i)
    print(pd.pivot_table(df1_pivots, index=i, values = 'avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Industry
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# ...

# %%
pd.pivot_table(df1_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk 
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nadil\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nadil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
